# %% [markdown]
# ###Imports

# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df_merged = pd.read_csv("/content/drive/MyDrive/capstone_data/df_merged.csv")

# %%
print(df_merged.head())
# Out:
#    Year State Area (SqMi)  Non-Renewable Generation (MWh)  \
# 0  2000    AK     665,384                       5154706.0
# 1  2000    AL      52,420                     114511544.0
# 2  2000    AR      53,179                      39911247.0
# 3  2000    AZ     113,990                      80587778.0
# 4  2000    CA     163,695                     147245036.0
#
#    Renewable Generation (MWh)  Total Generation (MWh)  Median Income ($)  \
# 0                   1001819.0               6156525.0              78675
# 1                   9893796.0             124405340.0              52737
# 2                   3964519.0              43875766.0              44211
# 3                   8358799.0              88946577.0              59226
# 4                  60837447.0             208082483.0              69696
#
#    Fossil Energy Consumption (BTU)  Renewable Energy Consumption (BTU)  \
# 0                        3497341.0                             10891.0
# ...

# %%
print(df_merged.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 19 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   Year                                1000 non-null   int64
#  1   State                               1000 non-null   object
#  2   Area (SqMi)                         1000 non-null   object
#  3   Non-Renewable Generation (MWh)      1000 non-null   float64
#  4   Renewable Generation (MWh)          1000 non-null   float64
#  5   Total Generation (MWh)              1000 non-null   float64
#  6   Median Income ($)                   1000 non-null   int64
#  7   Fossil Energy Consumption (BTU)     1000 non-null   float64
#  8   Renewable Energy Consumption (BTU)  1000 non-null   float64
#  9   Total Energy Consumption (BTU)      1000 non-null   float64
#  10  fossil_share                        1000 non-null   float64
# ...

# %%
print(df_merged.describe())
# Out:
#               Year  Non-Renewable Generation (MWh)  \
# count  1000.000000                    1.000000e+03
# mean   2009.500000                    7.117043e+07
# std       5.769167                    6.956687e+07
# min    2000.000000                    1.913000e+03
# 25%    2004.750000                    2.818861e+07
# 50%    2009.500000                    4.806723e+07
# 75%    2014.250000                    9.852594e+07
# max    2019.000000                    4.027307e+08
#
#        Renewable Generation (MWh)  Total Generation (MWh)  Median Income ($)  \
# count                1.000000e+03            1.000000e+03        1000.000000
# mean                 9.360694e+06            8.053113e+07       61207.766000
# std                  1.610184e+07            7.384670e+07        9807.786609
# min                  0.000000e+00            1.911207e+06       35548.000000
# 25%                  1.842939e+06            3.372816e+07       54048.250000
# ...

# %%
df_merged_state_summary = df_merged.groupby(['State','Year'], sort=True).sum()
df_merged_state_summary
# Out:
#            Area (SqMi)  Non-Renewable Generation (MWh)  \
# State Year
# AK    2000     665,384                       5154706.0
#       2001     665,384                       5397151.0
#       2002     665,384                       5315819.0
#       2003     665,384                       4750420.0
#       2004     665,384                       5019481.0
# ...                ...                             ...
# WY    2015      97,813                      44341549.0
#       2016      97,813                      41293805.0
#       2017      97,813                      41297567.0
#       2018      97,813                      41078452.0
#       2019      97,813                      36810274.0
#
#             Renewable Generation (MWh)  Total Generation (MWh)  \
# State Year
# AK    2000                   1001819.0               6156525.0
#       2001                   1346615.0               6743766.0
#       2002                   1451506.0               6767325.0
# ...

# %%
correalation_merged = df_merged.corr(numeric_only=True).round(2)

# %%
# Export to CSV (save to Google Drive)
correalation_merged.to_csv('/content/drive/My Drive/capstone_data/correalation_merged.csv', index=True)
