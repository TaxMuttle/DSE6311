# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df_egen = pd.read_excel("/content/drive/MyDrive/capstone_data/annual_generation_state.xls", skiprows=1, header=0)

# %%
df_egen
# Out:
#        YEAR STATE                         TYPE OF PRODUCER  \
# 0      1990    AK            Total Electric Power Industry
# 1      1990    AK            Total Electric Power Industry
# 2      1990    AK            Total Electric Power Industry
# 3      1990    AK            Total Electric Power Industry
# 4      1990    AK            Total Electric Power Industry
# ...     ...   ...                                      ...
# 62277  2023    WY  Electric Generators, Electric Utilities
# 62278  2023    WY  Electric Generators, Electric Utilities
# 62279  2023    WY  Electric Generators, Electric Utilities
# 62280  2023    WY  Electric Generators, Electric Utilities
# 62281  2023    WY  Electric Generators, Electric Utilities
#
#                     ENERGY SOURCE  GENERATION (Megawatthours)
# 0                           Total                   5599506.0
# 1                            Coal                    510573.0
# 2      Hydroelectric Conventional                    974521.0
# 3                     Natural Gas                   3466261.0
# 4                       Petroleum                    497116.0
# ...                           ...                         ...
# 62277                        Coal                  29830879.0
# 62278  Hydroelectric Conventional                    908133.0
# 62279                 Natural Gas                   1430842.0
# 62280                   Petroleum                     43712.0
# 62281                        Wind                   4945403.0
#
# [62282 rows x 5 columns]
# Warning: total number of rows (62282) exceeds max_rows (20000). Limiting to first (20000) rows.

# %%
df_egen = df_egen[df_egen['YEAR'] >= 2000]
df_egen = df_egen[df_egen['YEAR'] <= 2019]

# %%
df_egen
# Out:
#        YEAR STATE                         TYPE OF PRODUCER  \
# 15433  2000    AK            Total Electric Power Industry
# 15434  2000    AK            Total Electric Power Industry
# 15435  2000    AK            Total Electric Power Industry
# 15436  2000    AK            Total Electric Power Industry
# 15437  2000    AK            Total Electric Power Industry
# ...     ...   ...                                      ...
# 53752  2019    WY  Electric Generators, Electric Utilities
# 53753  2019    WY  Electric Generators, Electric Utilities
# 53754  2019    WY  Electric Generators, Electric Utilities
# 53755  2019    WY  Electric Generators, Electric Utilities
# 53756  2019    WY  Electric Generators, Electric Utilities
#
#                     ENERGY SOURCE  GENERATION (Megawatthours)
# 15433                       Total                   6156525.0
# 15434                        Coal                    538673.0
# 15435  Hydroelectric Conventional                   1001819.0
# 15436                 Natural Gas                   3975832.0
# 15437                   Petroleum                    640201.0
# ...                           ...                         ...
# 53752                        Coal                  34313690.0
# 53753  Hydroelectric Conventional                    984521.0
# 53754                 Natural Gas                    411640.0
# 53755                   Petroleum                     43547.0
# 53756                        Wind                   1853341.0
#
# [38324 rows x 5 columns]
# Warning: total number of rows (38324) exceeds max_rows (20000). Limiting to first (20000) rows.

# %%
df_egen = df_egen[df_egen['TYPE OF PRODUCER'] == "Total Electric Power Industry"]

# %%
df_egen
# Out:
#        YEAR STATE               TYPE OF PRODUCER  \
# 15433  2000    AK  Total Electric Power Industry
# 15434  2000    AK  Total Electric Power Industry
# 15435  2000    AK  Total Electric Power Industry
# 15436  2000    AK  Total Electric Power Industry
# 15437  2000    AK  Total Electric Power Industry
# ...     ...   ...                            ...
# 53734  2019    WY  Total Electric Power Industry
# 53735  2019    WY  Total Electric Power Industry
# 53736  2019    WY  Total Electric Power Industry
# 53737  2019    WY  Total Electric Power Industry
# 53738  2019    WY  Total Electric Power Industry
#
#                         ENERGY SOURCE  GENERATION (Megawatthours)
# 15433                           Total                   6156525.0
# 15434                            Coal                    538673.0
# 15435      Hydroelectric Conventional                   1001819.0
# 15436                     Natural Gas                   3975832.0
# 15437                       Petroleum                    640201.0
# ...                               ...                         ...
# 53734                     Other Gases                    285974.0
# 53735                           Other                     75488.0
# 53736                       Petroleum                     43730.0
# 53737  Solar Thermal and Photovoltaic                    180138.0
# 53738                            Wind                   4162818.0
#
# [10348 rows x 5 columns]

# %%
def categorize_energy(source):
    renewable_sources = [
        'Hydroelectric Conventional',
        'Geothermal',
        'Solar Thermal and Photovoltaic',
        'Wind',
        'Wood and Wood Derived Fuels',
        'Other Biomass',
        'Municipal Solid Waste',
        'Other Waste',
        'Other Renewable'
    ]
    if source == 'Total':
        return 'Total'
    elif source in renewable_sources:
        return 'Renewable'
    else:
        return 'Non-Renewable'

df_egen['Energy Category'] = df_egen['ENERGY SOURCE'].apply(categorize_energy)

df_categorized = df_egen.groupby(['YEAR', 'STATE', 'Energy Category'])['GENERATION (Megawatthours)'].sum().reset_index()

display(df_categorized.head())
# Out:
# /tmp/ipython-input-3240177711.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_egen['Energy Category'] = df_egen['ENERGY SOURCE'].apply(categorize_energy)
#    YEAR STATE Energy Category  GENERATION (Megawatthours)
# 0  2000    AK   Non-Renewable                   5154706.0
# 1  2000    AK       Renewable                   1001819.0
# 2  2000    AK           Total                   6156525.0
# 3  2000    AL   Non-Renewable                 114511544.0
# 4  2000    AL       Renewable                   9893796.0

# %%
df_categorized
# Out:
#       YEAR STATE Energy Category  GENERATION (Megawatthours)
# 0     2000    AK   Non-Renewable                   5154706.0
# 1     2000    AK       Renewable                   1001819.0
# 2     2000    AK           Total                   6156525.0
# 3     2000    AL   Non-Renewable                 114511544.0
# 4     2000    AL       Renewable                   9893796.0
# ...    ...   ...             ...                         ...
# 3096  2019    WV       Renewable                   3337109.0
# 3097  2019    WV           Total                  63925639.0
# 3098  2019    WY   Non-Renewable                  36810274.0
# 3099  2019    WY       Renewable                   5335383.0
# 3100  2019    WY           Total                  42145656.0
#
# [3101 rows x 4 columns]

# %%
df_pivot = df_categorized.pivot_table(
    index=['YEAR', 'STATE'],
    columns='Energy Category',
    values='GENERATION (Megawatthours)'
).reset_index()

display(df_pivot.head())
# Out:
# Energy Category  YEAR STATE  Non-Renewable   Renewable        Total
# 0                2000    AK      5154706.0   1001819.0    6156525.0
# 1                2000    AL    114511544.0   9893796.0  124405340.0
# 2                2000    AR     39911247.0   3964519.0   43875766.0
# 3                2000    AZ     80587778.0   8358799.0   88946577.0
# 4                2000    CA    147245036.0  60837447.0  208082483.0

# %%
df_pivot
# Out:
# Energy Category  YEAR STATE  Non-Renewable   Renewable        Total
# 0                2000    AK      5154706.0   1001819.0    6156525.0
# 1                2000    AL    114511544.0   9893796.0  124405340.0
# 2                2000    AR     39911247.0   3964519.0   43875766.0
# 3                2000    AZ     80587778.0   8358799.0   88946577.0
# 4                2000    CA    147245036.0  60837447.0  208082483.0
# ...               ...   ...            ...         ...          ...
# 1036             2019    VT         1913.0   2287885.0    2289798.0
# 1037             2019    WA     32182057.0  74281552.0  106463608.0
# 1038             2019    WI     56885038.0   5889260.0   62774299.0
# 1039             2019    WV     60588530.0   3337109.0   63925639.0
# 1040             2019    WY     36810274.0   5335383.0   42145656.0
#
# [1041 rows x 5 columns]

# %%
df_egen = df_pivot[df_pivot['STATE'] != "US-TOTAL"]
df_egen = df_egen[df_egen['STATE'] != "DC"]

# %%
df_egen
# Out:
# Energy Category  YEAR STATE  Non-Renewable   Renewable        Total
# 0                2000    AK      5154706.0   1001819.0    6156525.0
# 1                2000    AL    114511544.0   9893796.0  124405340.0
# 2                2000    AR     39911247.0   3964519.0   43875766.0
# 3                2000    AZ     80587778.0   8358799.0   88946577.0
# 4                2000    CA    147245036.0  60837447.0  208082483.0
# ...               ...   ...            ...         ...          ...
# 1036             2019    VT         1913.0   2287885.0    2289798.0
# 1037             2019    WA     32182057.0  74281552.0  106463608.0
# 1038             2019    WI     56885038.0   5889260.0   62774299.0
# 1039             2019    WV     60588530.0   3337109.0   63925639.0
# 1040             2019    WY     36810274.0   5335383.0   42145656.0
#
# [1009 rows x 5 columns]

# %%
# Export to CSV (save to Google Drive)
df_egen.to_csv('/content/drive/My Drive/capstone_data_cleaned/df_egen.csv', index=False)
